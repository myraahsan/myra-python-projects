# %% [markdown]
# # Import libraries

# %%
# Import libraries 
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import datasets

# %%
path = r'C:\Users\myra_\Documents\Instacart Basket Analysis 02-2023'

# %%
# Import the dataset 'order_products_prior.csv'
ords_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'order_products_prior.csv'), index_col = False)

# %%
# Check the output
ords_prods.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
# Import the dataset 'orders_checked.csv'
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared data', 'orders_checked.csv'), index_col = False)

# %%
# Deleting unneccassary columns 
del df_ords['Unnamed: 0']

# %%
del df_ords['eval_set']

# %%
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# To confirm the total size of the imported dataframe
df_ords.shape
# Out:
# (3421083, 6)

# %%
ords_prods.shape
# Out:
# (32434489, 4)

# %% [markdown]
# # Merging two dataframes

# %%
# %%time

ords_prods_key = ords_prods['order_id']

# Creating an empty shell to save the result
df_result = pd.DataFrame(columns=(df_ords.columns.append(ords_prods.columns)).unique())
df_result.to_csv(os.path.join(path, '02 Data', 'Prepared data', "orders_product_combined.csv"),index_label=False)

# Deleting ords_prods to save memory (the large one)
del(ords_prods)

# The basic idea is that we'll now load the large data set into chunks and then create a function that will 
# iteratively merge those chunks to the main data set 


# Define a function that will merge the chunks
def preprocess(x):
    ords_prods = pd.merge(df_ords,x, left_on = "order_id", right_on = "order_id")
    ords_prods.to_csv(os.path.join(path, '02 Data', 'Prepared data', "orders_product_combined.csv"),mode="a",header=False,index=False)

    
reader = pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'order_products_prior.csv'), chunksize=10000) # chunksize depends on you colsize

[preprocess(r) for r in reader]
# Out:
# Wall time: 1h 45min 12s
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
# Import the result to see what happened 

df_test = pd.read_csv(os.path.join(path, '02 Data', 'Prepared data', 'orders_product_combined.csv'))

# %%
df_test.shape
# Out:
# (32434489, 9)

# %%
df_test.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0        40      382            29                  1                 15
# 1        40      382            29                  1                 15
# 2        40      382            29                  1                 15
# 3        40      382            29                  1                 15
# 4       214      503             5                  0                 16
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                    23.0       10070                  1          1
# 1                    23.0       42450                  2          1
# 2                    23.0       33198                  3          1
# 3                    23.0       34866                  4          1
# 4                     9.0        5499                  1          0

# %% [markdown]
# # Export the file in pickle format

# %%
df_test.to_pickle(os.path.join(path, '02 Data', 'Prepared data', 'orders_products_combined.pkl'))
